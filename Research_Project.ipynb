# %% [markdown]
# <a href="https://colab.research.google.com/github/hameedjimoh312/Coding-School/blob/main/Research_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://github.com/frontiertechinstitute/datasets/tree/main/SB%20Close%20Approaches"

df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_6325/4277259349.py in <cell line: 0>()
#       1 url = "https://github.com/frontiertechinstitute/datasets/tree/main/SB%20Close%20Approaches"
#       2
# ----> 3 df = pd.read_csv(url)
#
# ...

# %%
df.head(10)
# Out:
#        Country                     region  Happiness Score      GDP  \
# 0  Switzerland             Western Europe            7.587  1.39651
# 1      Iceland             Western Europe            7.561  1.30232
# 2      Denmark             Western Europe            7.527  1.32548
# 3       Norway             Western Europe            7.522  1.45900
# 4       Canada              North America            7.427  1.32629
# 5      Finland             Western Europe            7.406  1.29025
# 6  Netherlands             Western Europe            7.378  1.32944
# 7       Sweden             Western Europe            7.364  1.33171
# 8  New Zealand  Australia and New Zealand            7.286  1.25018
# 9    Australia  Australia and New Zealand            7.284  1.33358
#
#    Social_support  Healthy Life_Expectancy  Freedom  corruptionperception  \
# 0         1.34951                  0.94143  0.66557               0.41978
# ...
