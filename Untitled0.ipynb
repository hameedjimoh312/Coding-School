# %% [markdown]
# <a href="https://colab.research.google.com/github/hameedjimoh312/Coding-School/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub
import os
import sys

# %%
path = kagglehub.dataset_download("berkayalan/stack-overflow-annual-developer-survey-2024")
survey_path = os.path.join(path, "survey_results_public.csv")
df = pd.read_csv(survey_path)
schema_path = os.path.join(path, "survey_results_schema.csv")
schema_df = pd.read_csv(schema_path)
# Out:
# Using Colab cache for faster access to the 'stack-overflow-annual-developer-survey-2024' dataset.

# %%
#replace null values with 0 vlaues from: YearsCode, YearsCodePro, WorkExp,
#remove : LearnCodeOnline,  DevTypes, BuyNewTool, Currency -- You can check how much of N/A is on the data set
#I want to use: 'Country' , 'LanguageHaveWorkedWith && LanguageWantToWorkWith' , AI section, TimeSearching

# %%
df.iloc[:, 98:115]
# Out:
#       ProfessionalCloud ProfessionalQuestion Industry  JobSatPoints_1  \
# 0                   NaN                  NaN      NaN             NaN
# 1                   NaN                  NaN      NaN             0.0
# 2                   NaN                  NaN      NaN             NaN
# 3                   NaN                  NaN      NaN             NaN
# 4                   NaN                  NaN      NaN             NaN
# ...                 ...                  ...      ...             ...
# 65432               NaN                  NaN      NaN             NaN
# 65433               NaN                  NaN      NaN             NaN
# 65434               NaN                  NaN      NaN             NaN
# 65435               NaN                  NaN      NaN             0.0
# 65436               NaN                  NaN      NaN             NaN
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# ...
